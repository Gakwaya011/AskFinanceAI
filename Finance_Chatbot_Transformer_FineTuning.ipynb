# %% [markdown]
# <a href="https://colab.research.google.com/github/Gakwaya011/AskFinanceAI/blob/main/Finance_Chatbot_Transformer_FineTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
data = load_dataset('majorSeaweed/financeQA_100K')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/610 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/94.0M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/5.19M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/5.26M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/5032 [00:00<?, ? examples/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'context', 'answer'],
#         num_rows: 90566
#     })
#     validation: Dataset({
#         features: ['question', 'context', 'answer'],
#         num_rows: 5031
#     })
#     test: Dataset({
#         features: ['question', 'context', 'answer'],
#         num_rows: 5032
#     })
# })

# %%
data_tr = load_dataset('majorSeaweed/financeQA_100K', split = 'train')

# %%
print(data_tr)
print(data_tr[0])
# Out:
# Dataset({
#     features: ['question', 'context', 'answer'],
#     num_rows: 90566
# })
# ...

# %%
data_tr.features
# Out:
# {'question': Value('string'),
#  'context': Value('string'),
#  'answer': Value('string')}

# %%
import pandas as pd

df = pd.DataFrame(data_tr)
print(df.head())
# Out:
#                                             question  \
# 0  What is the total estimated project cost menti...
# 1           Where should the payment be remitted to?
# 2  How does the high variation in payment types a...
# 3  Why might the document require historical curr...
# 4  How does RJR Nabisco's projected growth rate c...
#
#                                              context  \
# 0  ### Document Type\nThe image appears to be of ...
# 1  ### Document Type\nThe image depicts an invoic...
# 2  ### Document Type\nThis image depicts a financ...
# 3  ### Document Type\nThis is an invoice.\n\n### ...
# 4  ### Document Type:\n\nFinancial analysis docum...
#
#                                               answer
# 0  The grand total of the estimated project cost ...
# 1  The payment should be remitted to Wolf Knigh &...
# 2  The high variation in payment types and amount...
# 3  The document might require historical currency...
# 4  RJR Nabisco has a higher projected growth rate...

# %%
df.to_csv("financeQA_train.csv", index=False)

# %%
tf = pd.read_csv('/content/financeQA_train.csv')
tf.head(20)
# Out:
#                                              question  \
# 0   What is the total estimated project cost menti...
# 1            Where should the payment be remitted to?
# 2   How does the high variation in payment types a...
# 3   Why might the document require historical curr...
# 4   How does RJR Nabisco's projected growth rate c...
# 5   What was the total gross amount invoiced by Yo...
# 6   What is the estimated amount for the product 1...
# 7   What was the total sales revenue estimated for...
# 8       What is the historical context of the report?
# 9                         What is the invoice number?
# 10  What is the increase in amount from the previo...
# 11  What is the general account number associated ...
# 12           What is the budget code for the project?
# 13  What was the purpose of The Tobacco Institute'...
# 14  What is the amount of rent charged in the invo...
# 15  What can be inferred about the test material c...
# ...

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90566 entries, 0 to 90565
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  90566 non-null  object
#  1   context   90566 non-null  object
#  2   answer    90562 non-null  object
# dtypes: object(3)
# memory usage: 2.1+ MB

# %%
tf.describe()
# Out:
#                                 question  \
# count                              90566
# unique                             69493
# top     What is the date of the invoice?
# freq                                 768
#
#                                                   context  \
# count                                               90566
# unique                                               9212
# top     ### Document Type:\nThis appears to be a comme...
# freq                                                   18
#
#                        answer
# count                   90562
# unique                  84037
# top     The Tobacco Institute
# freq                      271
